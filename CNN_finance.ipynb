# %%
# import pytesseract
# from PIL import Image
import os
# from keras.preprocessing import image
# import matplotlib.pyplot as plt

# %%
# dataset_dir = 'D:\Research\CNN\Datasets\High'
os.chdir ('D:\Research\CNN\Datasets\Train\High')
os.getcwd()
# Out:
# 'D:\\Research\\CNN\\Datasets\\Train\\High'

# %%
img_path = r"D:\Research\CNN\Datasets\Train\High\2DA5E4RIT11M.jpg"
img = image.load_img(img_path)
plt.imshow(img)

# %%
import pytesseract
from PIL import Image

# The path to where the tesseract module is installed
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'  # Update this path if needed

image_path = r"D:\Research\CNN\Datasets\Train\High\2DA5E4RIT11M.jpg"
img = Image.open(image_path) # Perform OCR 
text = pytesseract.image_to_string(img) 
print(text)
# Out:
# 9751 2138 0470
